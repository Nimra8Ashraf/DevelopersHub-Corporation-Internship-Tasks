# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot  as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('heart_disease.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# # EDA and Data Cleaning & Preprocessing

# %% [markdown]
# # 1. Shape

# %%
df.shape
# Out:
# (918, 12)

# %% [markdown]
# # 2. Columns

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='str')

# %% [markdown]
# # 3. Info

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    str
#  2   ChestPainType   918 non-null    str
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    str
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    str
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    str
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 86.2 KB

# %% [markdown]
# # 4. Descriptive Summary

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %% [markdown]
# # 5. Null Values

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# # 6. Duplicates

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # 7. DataTypes

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                   str
# ChestPainType         str
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG            str
# MaxHR               int64
# ExerciseAngina        str
# Oldpeak           float64
# ST_Slope              str
# HeartDisease        int64
# dtype: object

# %% [markdown]
# # Data Visualization

# %% [raw]
# 1. Histogram for Numeric Variables

# %%
def plotting(var, num):
    plt.subplot(2, 2, num)
    sns.histplot(df[var], kde=True)
    
plotting('Age', 1)
plotting('RestingBP', 2)
plotting('Cholesterol', 3)
plotting('MaxHR', 4)


plt.tight_layout()
plt.show()

# %% [raw]
# 2. Count Plot for Categorical Values in comparison with HeartDisease

# %%
cat_features = df[['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope']]
for col in cat_features:
    plt.figure(figsize=(4,3))
    sns.countplot(x=df[col],palette='rainbow',hue=df['HeartDisease'])

# %%
# Box Plots for Numeric Features

# %%
numeric_values = df[['Age','RestingBP','Cholesterol','MaxHR','Oldpeak']]

for cols in numeric_values:
    plt.figure(figsize=(4,3))
    sns.boxplot(x=numeric_values[cols],palette='rainbow')
    plt.show()

# %%
# Data Cleaning & Preprocessing

# %% [raw]
# Heat Map

# %%
plt.figure(figsize=(6,5))
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %% [raw]
# Map sex into 0 and 1 for Male and Female

# %%
df['Sex'] = df['Sex'].map({'M': 0, 'F': 1})
df.head()
# Out:
#    Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40    0           ATA        140          289          0     Normal
# 1   49    1           NAP        160          180          0     Normal
# 2   37    0           ATA        130          283          0         ST
# 3   48    1           ASY        138          214          0     Normal
# 4   54    0           NAP        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %% [raw]
# Creating dummies

# %%
df_encode = pd.get_dummies(df,drop_first=True)
df_encode.head()
# Out:
#    Age  Sex  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40    0        140          289          0    172      0.0             0
# 1   49    1        160          180          0    156      1.0             1
# 2   37    0        130          283          0     98      0.0             0
# 3   48    1        138          214          0    108      1.5             1
# 4   54    0        150          195          0    122      0.0             0
#
#    ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  RestingECG_Normal  \
# 0               True              False             False               True
# 1              False               True             False               True
# 2               True              False             False              False
# 3              False              False             False               True
# 4              False               True             False               True
#
# ...

# %%
df_encode.columns
# Out:
# Index(['Age', 'Sex', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR',
#        'Oldpeak', 'HeartDisease', 'ChestPainType_ATA', 'ChestPainType_NAP',
#        'ChestPainType_TA', 'RestingECG_Normal', 'RestingECG_ST',
#        'ExerciseAngina_Y', 'ST_Slope_Flat', 'ST_Slope_Up'],
#       dtype='str')

# %%
# Feature Engineering & Feature Extraction

# %% [raw]
# 1. Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
cols = ['Age','RestingBP','Cholesterol','MaxHR','Oldpeak']
scaler = StandardScaler()
df_encode[cols] = scaler.fit_transform(df_encode[cols])

# %%
df_encode.head()
# Out:
#         Age  Sex  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# 0 -1.433140    0   0.410909     0.825070          0  1.382928 -0.832432
# 1 -0.478484    1   1.491752    -0.171961          0  0.754157  0.105664
# 2 -1.751359    0  -0.129513     0.770188          0 -1.525138 -0.832432
# 3 -0.584556    1   0.302825     0.139040          0 -1.132156  0.574711
# 4  0.051881    0   0.951331    -0.034755          0 -0.581981 -0.832432
#
#    HeartDisease  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0             0               True              False             False
# 1             1              False               True             False
# 2             0               True              False             False
# 3             1              False              False             False
# 4             0              False               True             False
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# ...

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_encode.drop('HeartDisease',axis=1)
y = df_encode['HeartDisease']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Create the model
model = LogisticRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Check accuracy
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8532608695652174
